# %%
# Copyright 2023, Acadential, All rights reserved.

# %% [markdown]
# # 14-14. PyTorch로 된 ResNet 뜯어보기

# %% [markdown]
# Torchvision에서는 다음과 같은 ResNet 모델들을 제공합니다:
# - "resnet18"
# - "resnet34"
# - "resnet50"
# - "resnet101"
# - "resnet152"
# - "resnext50_32x4d": [Aggregated Residual Transformations for Deep Neural Networks](https://arxiv.org/abs/1611.05431) 참고
# - "resnext101_32x8d": ""
# - "resnext101_64x4d:" ""
# - "wide_resnet50_2": [Wide Residual Networks](https://arxiv.org/abs/1605.07146) 참고
# - "wide_resnet101_2": ""
#
# 이번 시간에는 resnet 18, 34, 50, 101, 152만 살펴보도록 하겠습니다. resnext와 wide_resnet에 대해서 더 궁금하시다면 reference을 참고하시길 바랍니다.

# %%
from torchvision.models import (resnet18,
                                resnet34,
                                resnet50,
                                resnet101,
                                resnet152)
from torchsummary import summary

# %% [markdown]
# # ResNet 18

# %%
model = resnet18()

# %%
summary(model, (3, 64, 64))
# Out:
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ...
#             Conv2d-1           [-1, 64, 32, 32]           9,408
#        BatchNorm2d-2           [-1, 64, 32, 32]             128
#               ReLU-3           [-1, 64, 32, 32]               0
#          MaxPool2d-4           [-1, 64, 16, 16]               0
#             Conv2d-5           [-1, 64, 16, 16]          36,864
#        BatchNorm2d-6           [-1, 64, 16, 16]             128
#               ReLU-7           [-1, 64, 16, 16]               0
#             Conv2d-8           [-1, 64, 16, 16]          36,864
#        BatchNorm2d-9           [-1, 64, 16, 16]             128
#              ReLU-10           [-1, 64, 16, 16]               0
#        BasicBlock-11           [-1, 64, 16, 16]               0
#            Conv2d-12           [-1, 64, 16, 16]          36,864
#       BatchNorm2d-13           [-1, 64, 16, 16]             128
# ...

# %%
model
# Out:
# ResNet(
#   (conv1): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#   (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (relu): ReLU(inplace=True)
#   (maxpool): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#   (layer1): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# ...

# %% [markdown]
# # ResNet 34

# %%
model = resnet34()

# %%
summary(model, (3, 64, 64))
# Out:
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ...
#             Conv2d-1           [-1, 64, 32, 32]           9,408
#        BatchNorm2d-2           [-1, 64, 32, 32]             128
#               ReLU-3           [-1, 64, 32, 32]               0
#          MaxPool2d-4           [-1, 64, 16, 16]               0
#             Conv2d-5           [-1, 64, 16, 16]          36,864
#        BatchNorm2d-6           [-1, 64, 16, 16]             128
#               ReLU-7           [-1, 64, 16, 16]               0
#             Conv2d-8           [-1, 64, 16, 16]          36,864
#        BatchNorm2d-9           [-1, 64, 16, 16]             128
#              ReLU-10           [-1, 64, 16, 16]               0
#        BasicBlock-11           [-1, 64, 16, 16]               0
#            Conv2d-12           [-1, 64, 16, 16]          36,864
#       BatchNorm2d-13           [-1, 64, 16, 16]             128
# ...
